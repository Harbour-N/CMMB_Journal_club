# %% [markdown]
# # Quantifying Uncertainty and Robustness in a Biomathematical Model–Based Patient-Specific Response Metric for Glioblastoma
#
# This note book is based of and uses data from the following publication:
# Andrea Hawkins-Daarud et al. Quantifying Uncertainty and Robustness in a Biomathematical Model–Based Patient-Specific Response Metric for Glioblastoma. JCO Clin Cancer Inform 3, 1-8(2019).
# DOI:10.1200/CCI.18.00066

# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Laod in data
df = pd.read_csv('ds_cci.18.00066.csv')

# %%
df
# Out:
#     Patient ID  First_date_T1DG_Min  First_date_T1DG_Max  \
# 0            1                16.87                17.40
# 1            2                18.24                18.60
# 2            3                 5.78                 6.37
# 3            4                13.05                13.56
# 4            5                21.16                22.43
# ..         ...                  ...                  ...
# 58          59                15.27                15.96
# 59          60                13.16                13.30
# 60          61                22.52                23.17
# 61          62                 4.58                 6.91
# 62          63                 9.08                10.22
#
#     First Date FLAIR_Min   First Date FLAIR_Max  Second_data_T1Gd_Min  \
# 0                   18.34                 19.37                 18.15
# 1                   27.94                 29.63                 20.49
# 2                    8.92                 10.34                  9.73
# 3                   20.77                 20.86                 11.63
# 4                   32.18                 32.63                 22.52
# ..                    ...                   ...                   ...
# 58                  19.67                 21.19                 16.67
# 59                  18.58                 19.28                 14.38
# 60                  25.78                 25.87                 23.95
# 61                  26.30                 27.00                  5.82
# 62                  24.11                 24.51                 10.07
#
#     Second_data_T1Gd_Max  PostTX_Min  PostTX_Max  dt_1  dt_2
# 0                  18.55       13.54       13.97    55   111
# 1                  21.15       11.97       12.03    11   147
# 2                  10.10        5.33        5.33    14   135
# 3                  11.88        5.53        5.74     5   102
# 4                  22.69       21.86       21.98     3    62
# ..                   ...         ...         ...   ...   ...
# 58                 17.56       12.26       12.47     3    99
# 59                 14.90        9.83       11.82     9    95
# 60                 24.09       10.64       11.16    24   109
# 61                  6.52        9.45        9.45     5    98
# 62                 10.40        6.03        8.19     7    92
#
# [63 rows x 11 columns]
